# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Create a Dataframe

# %%
data = np.random.random(size=(5,3))
df = pd.DataFrame(data=data,columns=['A','B','C'])
df
# Out:
#           A         B         C
# 0  0.206738  0.333917  0.799792
# 1  0.565995  0.654560  0.756543
# 2  0.335366  0.480938  0.677712
# 3  0.915381  0.865272  0.904420
# 4  0.877419  0.424353  0.708024

# %%
# Dataframe can be created by dictionary
df_1 = pd.DataFrame(data={'A':[1,2,3],'B':['Wally','Louis','Weber']})
df_1
# Out:
#    A      B
# 0  1  Wally
# 1  2  Louis
# 2  3  Weber

# %%
# Rarely be used, but below shows dataframe can be created by array
dtype = [("A", np.int), ("B",(np.str,20))]
data = np.array([(1,"Wally"),(2,"Louis"),(3,"Weber")],dtype=dtype)
df_2 = pd.DataFrame(data)
df_2
# Out:
#    A      B
# 0  1  Wally
# 1  2  Louis
# 2  3  Weber

# %% [markdown]
# # Save Data

# %%
#create a random dataframe
df = pd.DataFrame(np.random.random(size=(10000,4)), columns=["A","B","C","D"])
df.head()
# Out:
#           A         B         C         D
# 0  0.062732  0.707788  0.101589  0.804802
# 1  0.966833  0.048555  0.768761  0.236874
# 2  0.253198  0.585534  0.144452  0.798012
# 3  0.402180  0.737105  0.883524  0.230446
# 4  0.554016  0.970527  0.168389  0.396220

# %%
#save the file to csv
df.to_csv("save.csv", index=False, float_format="%0.4f")
#there are many different formats can be saved
#df.to_pickle("save.pkl")
#df.to_hdf("save.hdf")

# %%
#show the files in the current folder
# %ls
# Out:
# AB_NYC_2019.csv           heart.csv                 plots.png
# PyDataManupulation.ipynb  meteorite-landings.csv    save.csv
# README.md                 output.pdf                train.csv
# astronauts.csv            output.png

# %%
#read the file from csv
df = pd.read_csv("save.csv")
df.head()
# Out:
#         A       B       C       D
# 0  0.0627  0.7078  0.1016  0.8048
# 1  0.9668  0.0486  0.7688  0.2369
# 2  0.2532  0.5855  0.1445  0.7980
# 3  0.4022  0.7371  0.8835  0.2304
# 4  0.5540  0.9705  0.1684  0.3962

# %% [markdown]
# # Inspecting Data

# %%
df.info(), df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       10000 non-null  float64
#  1   B       10000 non-null  float64
#  2   C       10000 non-null  float64
#  3   D       10000 non-null  float64
# dtypes: float64(4)
# memory usage: 312.6 KB
# (None,
#                    A             B             C             D
#  count  10000.000000  10000.000000  10000.000000  10000.000000
#  mean       0.498439      0.495804      0.501505      0.498187
#  std        0.289429      0.287449      0.287734      0.289151
#  min        0.000300      0.000100      0.000000      0.000000
#  25%        0.248175      0.246975      0.250975      0.247175
#  50%        0.498050      0.494750      0.500850      0.496800
#  75%        0.750625      0.742350      0.752525      0.748375
#  max        1.000000      1.000000      0.999900      0.999900)

# %%
df.sample(3)
# Out:
#            A       B       C       D
# 6603  0.8844  0.4557  0.0049  0.6232
# 268   0.5183  0.5869  0.0987  0.3340
# 9218  0.6264  0.2747  0.2614  0.1863

# %%
df.head()
# Out:
#         A       B       C       D
# 0  0.0627  0.7078  0.1016  0.8048
# 1  0.9668  0.0486  0.7688  0.2369
# 2  0.2532  0.5855  0.1445  0.7980
# 3  0.4022  0.7371  0.8835  0.2304
# 4  0.5540  0.9705  0.1684  0.3962

# %%
df.tail()
# Out:
#            A       B       C       D
# 9995  0.7284  0.0577  0.4514  0.1882
# 9996  0.5036  0.9798  0.7263  0.8667
# 9997  0.5012  0.8043  0.9238  0.5046
# 9998  0.7250  0.9077  0.2010  0.2985
# 9999  0.7473  0.7508  0.6263  0.7815

# %%
df.corr()
# Out:
#           A         B         C         D
# A  1.000000  0.001173 -0.015358  0.003445
# B  0.001173  1.000000 -0.012335  0.018564
# C -0.015358 -0.012335  1.000000  0.001800
# D  0.003445  0.018564  0.001800  1.000000

# %%
df["A"].value_counts()
# Out:
# 0.7037    7
# 0.5090    6
# 0.8605    6
# 0.7048    6
# 0.5632    5
#          ..
# 0.2437    1
# 0.0779    1
# 0.7896    1
# 0.6457    1
# 1.0000    1
# Name: A, Length: 6337, dtype: int64

# %%
df.max()
# Out:
# A    1.0000
# B    1.0000
# C    0.9999
# D    0.9999
# dtype: float64

# %% [markdown]
# # Basic Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# load file
df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# # Bar Plot

# %%
# create a dataframe grouping by cp and re-add index
chest_pain = df.groupby(by="cp").median().reset_index()
chest_pain.head()
# Out:
#    cp   age  sex  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   0  57.0  1.0     130.0  248.0  0.0      0.0    143.0    1.0      1.2
# 1   1  52.0  1.0     128.0  238.0  0.0      1.0    163.5    0.0      0.0
# 2   2  53.0  1.0     130.0  233.0  0.0      1.0    158.0    0.0      0.5
# 3   3  59.0  1.0     140.0  234.0  0.0      0.0    159.0    0.0      1.2
#
#    slope   ca  thal  target
# 0    1.0  1.0   3.0     0.0
# 1    2.0  0.0   2.0     1.0
# 2    2.0  0.0   2.0     1.0
# 3    1.0  0.0   2.0     1.0

# %%
# plot by using pandas
# plot the bar chart: cp vs. age
chest_pain.plot.bar(x="cp", y="age")

# %%
# plot the bar chart: all related to cp
chest_pain.plot.bar(x="cp")

# %%
# plot by using matplotlib
fig, ax = plt.subplots()
ax.bar(chest_pain["cp"], chest_pain["age"], label="age",
      edgecolor="k", color=["red","blue","green","yellow"])
ax.set_xlabel("cp")
ax.set_xticks(chest_pain["cp"])

# %%
# plot by using seaborn
ax = sb.barplot("cp","age",errcolor='k',capsize=0.2,data=df)

# %% [markdown]
# # Scatter Plot

# %%
# plot by using pandas
df.plot.scatter("age","trestbps")

# %%
# plot by using matplotlib
fig, ax = plt.subplots()
ax.scatter(df["age"],df["trestbps"], marker="^",
          s=60, c=df["age"], edgecolors="k", alpha=0.5)
ax.set_xlabel("age")
ax.set_ylabel("trestbps")
# Out:
# Text(0, 0.5, 'trestbps')

# %%
# plot by seaborn
ax = sb.scatterplot("age","trestbps",hue="age",s=30,edgecolor="none",data=df)

# %% [markdown]
# # Line Plot

# %%
# group ages
ages = df.groupby("age").median().reset_index()
ages.head(), ages.shape
# Out:
# (   age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
#  0   29  1.0  1.0     130.0  204.0  0.0      0.0    202.0    0.0     0.00
#  1   34  0.5  2.0     118.0  196.0  0.0      0.5    183.0    0.0     0.35
#  2   35  1.0  0.0     124.0  195.0  0.0      1.0    165.0    0.5     0.70
#  3   37  0.5  2.0     125.0  232.5  0.0      1.0    178.5    0.0     1.75
#  4   38  1.0  2.0     138.0  175.0  0.0      1.0    173.0    0.0     0.00
#
#     slope   ca  thal  target
#  0    2.0  0.0   2.0     1.0
#  1    2.0  0.0   2.0     1.0
#  2    2.0  0.0   2.5     0.5
#  3    1.0  0.0   2.0     1.0
#  4    2.0  4.0   2.0     1.0  ,
#  (41, 14))

# %%
# plot by using pandas
ages.plot.line("age","chol")

# %%
ages.plot.line("age",["chol", "trestbps"])

# %%
# plot by using matplotlib
fig, ax = plt.subplots()
ax.plot(ages["age"], ages["trestbps"], ls=":", lw=1.7)
ax.set_xlabel("age")
ax.set_ylabel("trestbps")
# Out:
# Text(0, 0.5, 'trestbps')

# %%
# plot by using seaborn
sb.lineplot("age","trestbps",data=ages)

# %% [markdown]
# # Plotting Methods - Pandas vs. Others

# %%
fig, axes = plt.subplots(ncols=2) # create two columns plotting area
df.plot.scatter(x="age",y="chol",ax=axes[0]) # plot on 1st area by using pandas
df.plot.scatter(x="age",y="trestbps",ax=axes[1]) # plot on second area by using pandas
fig.tight_layout() # ensure no overlapping between these two charts

# %%
# save the plots
fig2 = axes[0].get_figure()
fig2.savefig("plots.png",bbox_inches="tight",transparent=True)
fig2

# %%
# modify the plotting layout
with plt.style.context("default"):
    fig, axes = plt.subplots(ncols=3, sharey=True,
                            gridspec_kw={"width_ratios":[2,1,1],"wspace":0})
    y = "age"
    xs = ["chol", "trestbps", "thalach"]
    for x, ax in zip(xs, axes):
        ax.scatter(df[x], df[y])
        ax.set_xlabel(x)
    axes[0].set_ylabel(y)
    fig.savefig("output.png", dpi=100, bbox_inches="tight")
    fig.savefig("output.pdf", dpi=100, bbox_inches="tight")

# %% [markdown]
# # Visualing 1D Distribution

# %% [markdown]
# # 1. Histograms

# %%
df["age"].plot.hist(bins=30);
# df.age.plot.hist(bins=30);
# plt.hist(df.age, bins=30);

# %%
fig, ax = plt.subplots()
ax.hist(df.trestbps, bins=20, histtype="step", label="trestbps")
ax.hist(df.thalach, bins=20, histtype="stepfilled", label="thalach", alpha=0.3, edgecolor="w")
ax.legend();

# %% [markdown]
# # 2. Box Plots

# %% [markdown]
# Shows mean, quartiles, IQR and outliers. IQR is inter-quartile range = (75% - 25%). Outliers are points more than 1.5 * IQR away

# %%
df[["trestbps","thalach"]].plot.box();

# %%
df[["trestbps","thalach"]].describe()
# Out:
#          trestbps     thalach
# count  303.000000  303.000000
# mean   131.623762  149.646865
# std     17.538143   22.905161
# min     94.000000   71.000000
# 25%    120.000000  133.500000
# 50%    130.000000  153.000000
# 75%    140.000000  166.000000
# max    200.000000  202.000000

# %%
# when plotting by matplotlib, it requires arrays
plt.boxplot(df[["trestbps","thalach"]].to_numpy());

# %%
# plot by seaborn
sb.boxplot(data=df[["trestbps","thalach"]]);

# %%
sb.boxplot(x="cp", y="trestbps", data=df);

# %% [markdown]
# # Violin Plots

# %%
fig, ax = plt.subplots()
ax.violinplot(df[["trestbps", "thalach"]].to_numpy());

# %%
# control the bandwidth to control the smoothing.
fig, ax = plt.subplots()
ax.violinplot(df[["trestbps", "thalach"]].to_numpy(), bw_method=0.2);

# %%
# plot by seaborn
sb.violinplot(data=df[["trestbps", "thalach"]], inner="quartile", bw=0.2);

# %% [markdown]
# # Bee Swarm Plots

# %%
sb.swarmplot(data=df[["trestbps", "thalach"]], size=3);

# %%
sb.violinplot(data=df[["trestbps", "thalach"]], inner=None);
sb.swarmplot(data=df[["trestbps", "thalach"]], size=2, color="k", alpha=0.5);

# %% [markdown]
# # Visualizing 2D data

# %%
df = pd.read_csv("meteorite-landings.csv")
df.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
df.dropna(subset=["reclong","reclat"])
df = df[df.reclong<300]

# %% [markdown]
# # 2D Histograms

# %%
plt.hist2d(df.reclong, df.reclat, bins=200, vmax=4)
plt.colorbar();

# %% [markdown]
# # 2D Hex Plots

# %%
plt.hexbin(df.reclong, df.reclat, bins=200, vmax=4, lw=0.0)
plt.colorbar();

# %%
df.plot.hexbin(x="reclong", y="reclat", vmax=4, gridsize=100, linewidth=0.25);

# %% [markdown]
# # Contour

# %%
# create a dataset
spacing = np.linspace(0, 10, 200)
X, Y = np.meshgrid(spacing, spacing)
Z = (np.sin(X) + np.cos(Y) + 2 * np.arcsinh(X * Y))**2

plt.contour(X, Y, Z, levels=20)
plt.colorbar();

# %%
c = plt.contour(X, Y, Z, levels=20)
plt.clabel(c, inline=True, fmt="%0.1f")
plt.colorbar();

# %%
c = plt.contourf(X, Y, Z, levels=20)
plt.colorbar();

# %%
plt.contourf(X, Y, Z, levels=10)
c = plt.contour(X, Y, Z, levels=10, colors="black")
plt.clabel(c, inline=True, fmt="%0.1f");

# %% [markdown]
# # KDE

# %%
# This is called rejection sampling, a way to brute force sample any surface, so long
# as you're fine waiting for slow code
n = 50000
xs, ys = np.random.uniform(0, 10, n), np.random.uniform(0, 10, n)
zs = (np.sin(xs) + np.cos(ys) + 2 * np.arcsinh(xs * ys))**2
zs /= zs.max()
passed = np.random.uniform(0, 1, n) < zs
xs, ys = xs[passed], ys[passed]
plt.scatter(xs, ys, s=1, alpha=0.2);

# %%
sb.kdeplot(xs, ys);

# %%
sb.kdeplot(xs, ys, bw=2.0);

# %%
sb.kdeplot(xs, ys, bw=0.2);

# %% [markdown]
# # Jointplots

# %% [markdown]
# Joint plots allow you to swap out the interior and marginal plots to get something the perfectly suits your needs.

# %%
sb.jointplot(data=df, x="reclong", y="reclat");

# %%
sb.jointplot(data=df, x="reclong", y="reclat", kind="hex", 
             gridsize=100, vmax=3, linewidth=0, marginal_kws={"bins": 100});

# %%
sb.jointplot(x=xs, y=ys, kind="kde");

# %%
sb.jointplot(x=xs, y=ys, kind="hex", gridsize=20, cmap="magma");

# %%
sb.pairplot(data=df[["reclat", "reclong", "mass"]]);

# %% [markdown]
# # Pandas Styling for Tables

# %%
df = pd.DataFrame(np.random.normal(size=(6,6)), columns=[x for x in "ABCDEF"])
df
# Out:
#           A         B         C         D         E         F
# 0  1.755630  0.602956  0.423487  0.971732  2.304083 -0.752119
# 1  0.203449 -0.208228  0.977497  0.296297  0.963239  0.023061
# 2 -0.883630 -0.283018  0.887692  1.124224 -0.177318  0.175841
# 3  0.485014 -0.937344 -1.078037  0.217590 -0.171473  1.116007
# 4 -0.577692  1.434195 -0.321463  0.879635 -0.608355 -0.224454
# 5 -0.114022  1.881177 -1.449562 -0.661679  1.905971  0.408877

# %%
# create a function when the column value is less than 0, show red 
def neg_red(x):
    return f"color: {'red' if x < 0 else 'white'}"
df.style.applymap(neg_red)
# Out:
# <style  type="text/css" >
#     #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row0_col0 {
#             color:  white;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row0_col1 {
#             color:  white;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row0_col2 {
#             color:  white;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row0_col3 {
#             color:  white;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row0_col4 {
#             color:  white;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row0_col5 {
#             color:  red;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row1_col0 {
#             color:  white;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row1_col1 {
#             color:  red;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row1_col2 {
#             color:  white;
#         }    #T_2e27e06e_b4d3_11ea_8e8b_d4619d145e96row1_col3 {
#             color:  white;
# ...

# %%
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (xs == m).replace(color)
    return is_max
df.style.apply(gold_max, axis=None)
# Out:
# <style  type="text/css" >
#     #T_2e3aa820_b4d3_11ea_8e8b_d4619d145e96row0_col4 {
#             background-color:  #c78f2e;
#         }</style><table id="T_2e3aa820_b4d3_11ea_8e8b_d4619d145e96" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e3aa820_b4d3_11ea_8e8b_d4619d145e96level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2e3aa820_b4d3_11ea_8e8b_d4619d145e96row0_col0" class="data row0 col0" >1.755630</td>
#                         <td id="T_2e3aa820_b4d3_11ea_8e8b_d4619d145e96row0_col1" class="data row0 col1" >0.602956</td>
# ...

# %%
df.style.background_gradient(cmap="magma")
# Out:
# <style  type="text/css" >
#     #T_2e4a51d0_b4d3_11ea_8e8b_d4619d145e96row0_col0 {
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }    #T_2e4a51d0_b4d3_11ea_8e8b_d4619d145e96row0_col1 {
#             background-color:  #c83e73;
#             color:  #f1f1f1;
#         }    #T_2e4a51d0_b4d3_11ea_8e8b_d4619d145e96row0_col2 {
#             background-color:  #fd9266;
#             color:  #000000;
#         }    #T_2e4a51d0_b4d3_11ea_8e8b_d4619d145e96row0_col3 {
#             background-color:  #fed799;
#             color:  #000000;
#         }    #T_2e4a51d0_b4d3_11ea_8e8b_d4619d145e96row0_col4 {
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }    #T_2e4a51d0_b4d3_11ea_8e8b_d4619d145e96row0_col5 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_2e4a51d0_b4d3_11ea_8e8b_d4619d145e96row1_col0 {
#             background-color:  #912b81;
#             color:  #f1f1f1;
# ...

# %%
df.abs().style.bar(align="left", width=90)
# Out:
# <style  type="text/css" >
#     #T_2e534164_b4d3_11ea_8e8b_d4619d145e96row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }    #T_2e534164_b4d3_11ea_8e8b_d4619d145e96row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.2%, transparent 21.2%);
#         }    #T_2e534164_b4d3_11ea_8e8b_d4619d145e96row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.1%, transparent 8.1%);
#         }    #T_2e534164_b4d3_11ea_8e8b_d4619d145e96row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 74.9%, transparent 74.9%);
#         }    #T_2e534164_b4d3_11ea_8e8b_d4619d145e96row0_col4 {
#             width:  10em;
#              height:  80%;
# ...

# %%
head = {"selector": "th", "props": [("text-align", "center")]}
df.style.set_table_styles([head]).bar(align="mid", color=['red', 'green'], vmin=-3, vmax=3)
# Out:
# <style  type="text/css" >
#     #T_2e5c89e0_b4d3_11ea_8e8b_d4619d145e96 th {
#           text-align: center;
#     }    #T_2e5c89e0_b4d3_11ea_8e8b_d4619d145e96row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 79.3%, transparent 79.3%);
#         }    #T_2e5c89e0_b4d3_11ea_8e8b_d4619d145e96row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 60.0%, transparent 60.0%);
#         }    #T_2e5c89e0_b4d3_11ea_8e8b_d4619d145e96row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 57.1%, transparent 57.1%);
#         }    #T_2e5c89e0_b4d3_11ea_8e8b_d4619d145e96row0_col3 {
#             width:  10em;
#              height:  80%;
# ...

# %%
df.style.bar(align="mid", width=50).apply(gold_max, axis=None).applymap(neg_red)
# Out:
# <style  type="text/css" >
#     #T_2e717ba2_b4d3_11ea_8e8b_d4619d145e96row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.7%, #d65f5f 16.7%, #d65f5f 50.0%, transparent 50.0%);
#             : ;
#             color:  white;
#         }    #T_2e717ba2_b4d3_11ea_8e8b_d4619d145e96row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.6%, #d65f5f 16.6%, #d65f5f 27.3%, transparent 27.3%);
#             : ;
#             color:  white;
#         }    #T_2e717ba2_b4d3_11ea_8e8b_d4619d145e96row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 29.9%, #d65f5f 29.9%, #d65f5f 38.6%, transparent 38.6%);
#             : ;
#             color:  white;
#         }    #T_2e717ba2_b4d3_11ea_8e8b_d4619d145e96row0_col3 {
#             width:  10em;
# ...

# %% [markdown]
# # Visualizing ND Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
from sklearn import manifold

df = pd.read_csv("heart.csv")
target = df["target"].to_numpy()
df = df[["age", "sex", "cp", "trestbps", "chol", "thalach"]]
df.head()
# Out:
#    age  sex  cp  trestbps  chol  thalach
# 0   63    1   3       145   233      150
# 1   37    1   2       130   250      187
# 2   41    0   1       130   204      172
# 3   56    1   1       120   236      178
# 4   57    0   0       120   354      163

# %% [markdown]
# # Scatter Matrix

# %%
pd.plotting.scatter_matrix(df);

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol   thalach
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678 -0.398522
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912 -0.044020
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.295762
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174 -0.046698
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000 -0.009940
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940  1.000000

# %%
sb.heatmap(df.corr(),annot=True,fmt="0.2f",square=True);

# %% [markdown]
# # 4D Spiral

# %%
np.random.seed(0)
n = 2000
t = np.linspace(0, 20, n)
x = t * np.sin(t) + 0.2 * np.random.normal(size=n)
y = t * np.cos(t) + 0.2 * np.random.normal(size=n)
z = np.log(t + 1) * np.sin(np.sqrt(t)) + 0.1 * np.random.normal(size=n)
a = np.log(t + 1) * np.cos(np.sqrt(t)) + 0.1 * np.random.normal(size=n)

df2 = pd.DataFrame({"x": x, "y": y, "z": z, "a": a})
data = df2.to_numpy()

# %%
pd.plotting.scatter_matrix(df2);

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x, y, z, c=t, s=3+a);

# %% [markdown]
# # Manifold Learning

# %% [markdown]
# See https://scikit-learn.org/stable/modules/manifold.html

# %%
methods = [
    ("LLE", manifold.LocallyLinearEmbedding(n_neighbors=20, method='standard')),
    ("LTSA", manifold.LocallyLinearEmbedding(n_neighbors=20, method='ltsa')),
    ("Hessian LLE", manifold.LocallyLinearEmbedding(n_neighbors=20, method='hessian')),
    ("Modified LLE", manifold.LocallyLinearEmbedding(n_neighbors=20, method='modified')),
    ("Isomap", manifold.Isomap()),
    ("MDS", manifold.MDS(n_init=1)),
    ("SE", manifold.SpectralEmbedding()),
    ("t-SNE", manifold.TSNE()),
]

fig, axes = plt.subplots(nrows=2, ncols=4)
for (name, method), ax in zip(methods, axes.flatten()):
    print(f"Running {name}")
    Y = method.fit_transform(data)
    ax.scatter(Y[:, 0], Y[:, 1], c=t)
    ax.set_title(name)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
# Out:
# Running LLE
# Running LTSA
# Running Hessian LLE
# Running Modified LLE
# Running Isomap
# Running MDS
# Running SE
# Running t-SNE

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
for (name, method), ax in zip(methods, axes.flatten()):
    print(f"Running {name}")
    try:
        Y = method.fit_transform(df.to_numpy())
        ax.scatter(Y[:, 0], Y[:, 1], c=target)
    except Exception:
        print(f"Method {name} failed")
    ax.set_title(name)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
# Out:
# Running LLE
# Running LTSA
# /Users/ycliu3/opt/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.py:937: LinAlgWarning: Diagonal number 86 is exactly zero. Singular matrix.
#   self.M_lu = lu_factor(M)
# Running Hessian LLE
# Method Hessian LLE failed
# Running Modified LLE
# Running Isomap
# Running MDS
# Running SE
# Running t-SNE
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /Users/ycliu3/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:722: UserWarning: Warning: converting a masked element to nan.
#   data = np.array(a, copy=False, subok=subok)

# %% [markdown]
# # Basics - Indexing, Labeling and Ordering

# %% [markdown]
# Data source: https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# # Indexing

# %%
# set id as the index of the dataframe
df_2 = df.set_index("id")
df_2
# Out:
#                                                        name   host_id  \
# id
# 2539                     Clean & quiet apt home by the park      2787
# 2595                                  Skylit Midtown Castle      2845
# 3647                    THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3831                        Cozy Entire Floor of Brownstone      4869
# 5022       Entire Apt: Spacious Studio/Loft by central park      7192
# ...                                                     ...       ...
# 36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 36485431            Sunny Studio at Historical Neighborhood  23492952
# 36485609               43rd St. Time Square-cozy single bed  30985759
# 36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#               host_name neighbourhood_group       neighbourhood  latitude  \
# id
# ...

# %%
# search name by id as index
df_2.name[5022]
# Out:
# 'Entire Apt: Spacious Studio/Loft by central park'

# %%
# group the data by room_type and show the mean of data
df_3 = df.groupby("room_type").mean()
df_3
# Out:
#                            id       host_id   latitude  longitude       price  \
# room_type
# Entire home/apt  1.843818e+07  6.175593e+07  40.728649 -73.960696  211.794246
# Private room     1.946893e+07  7.247514e+07  40.729208 -73.942924   89.780973
# Shared room      2.300378e+07  1.026241e+08  40.730514 -73.943343   70.127586
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt        8.506907          22.842418           1.306578
# Private room           5.377900          24.112962           1.445209
# Shared room            6.475000          16.600000           1.471726
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                       10.698335        111.920304
# Private room                           3.227717        111.203933
# Shared room                            4.662931        162.000862

# %%
# reset the index
df_3.reset_index()
# Out:
#          room_type            id       host_id   latitude  longitude  \
# 0  Entire home/apt  1.843818e+07  6.175593e+07  40.728649 -73.960696
# 1     Private room  1.946893e+07  7.247514e+07  40.729208 -73.942924
# 2      Shared room  2.300378e+07  1.026241e+08  40.730514 -73.943343
#
#         price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0  211.794246        8.506907          22.842418           1.306578
# 1   89.780973        5.377900          24.112962           1.445209
# 2   70.127586        6.475000          16.600000           1.471726
#
#    calculated_host_listings_count  availability_365
# 0                       10.698335        111.920304
# 1                        3.227717        111.203933
# 2                        4.662931        162.000862

# %%
# drop the original index and reset index
df_3.reset_index(drop=True)
# Out:
#              id       host_id   latitude  longitude       price  \
# 0  1.843818e+07  6.175593e+07  40.728649 -73.960696  211.794246
# 1  1.946893e+07  7.247514e+07  40.729208 -73.942924   89.780973
# 2  2.300378e+07  1.026241e+08  40.730514 -73.943343   70.127586
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0        8.506907          22.842418           1.306578
# 1        5.377900          24.112962           1.445209
# 2        6.475000          16.600000           1.471726
#
#    calculated_host_listings_count  availability_365
# 0                       10.698335        111.920304
# 1                        3.227717        111.203933
# 2                        4.662931        162.000862

# %% [markdown]
# # Sorting

# %% [markdown]
# There are two ways to sort values: `sort_index` or `sort_value`

# %%
# sort the data by dscending Z-A (default is ascending)
df_3.sort_index(ascending=False)
# Out:
#                            id       host_id   latitude  longitude       price  \
# room_type
# Shared room      2.300378e+07  1.026241e+08  40.730514 -73.943343   70.127586
# Private room     1.946893e+07  7.247514e+07  40.729208 -73.942924   89.780973
# Entire home/apt  1.843818e+07  6.175593e+07  40.728649 -73.960696  211.794246
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Shared room            6.475000          16.600000           1.471726
# Private room           5.377900          24.112962           1.445209
# Entire home/apt        8.506907          22.842418           1.306578
#
#                  calculated_host_listings_count  availability_365
# room_type
# Shared room                            4.662931        162.000862
# Private room                           3.227717        111.203933
# Entire home/apt                       10.698335        111.920304

# %%
# sort the value by neighbourhood_group and host_name
df.sort_values(["neighbourhood_group","host_name"])
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
# show the unique values in neighbourhood_group
df.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
# count the values in neighbourhood_group
df.neighbourhood_group.value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# sort the values by multiple requirements
df.sort_values(["neighbourhood_group","host_name"],ascending=[False,True],inplace=True)
df.head(3)
# Out:
#              id                                         name   host_id  \
# 4079    2611458           close to Manhattan country setting  13373889
# 16714  13370393                                    Charming.  13373889
# 24922  19970350  Newly renovated clean and Cozy Private room  15344412
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 4079      Aaron       Staten Island          Concord  40.60375  -74.08065
# 16714     Aaron       Staten Island          Concord  40.60556  -74.08274
# 24922       Abe       Staten Island  New Springville  40.58085  -74.15443
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 4079      Private room    129               1                 40  2018-10-14
# 16714  Entire home/apt    150               7                  1  2018-11-04
# 24922     Private room     43              10                  0         NaN
#
# ...

# %% [markdown]
# # Rank

# %%
dfp = df.sort_values("price",ascending=False)
dfp[["id","host_name","price"]].head(5)
# Out:
#              id host_name  price
# 9151    7003697  Kathrine  10000
# 17692  13894339      Erin  10000
# 29238  22436899    Jelena  10000
# 12342   9528920       Amy   9999
# 40433  31340283      Matt   9999

# %%
# add another column called price_rank and assign a rank
dfp["price_rank"] = dfp.price.rank(method="min",ascending=False)
dfp[["id", "host_name", "price", "price_rank"]].head(5)
# Out:
#              id host_name  price  price_rank
# 9151    7003697  Kathrine  10000         1.0
# 17692  13894339      Erin  10000         1.0
# 29238  22436899    Jelena  10000         1.0
# 12342   9528920       Amy   9999         4.0
# 40433  31340283      Matt   9999         4.0

# %% [markdown]
# # Basics - Slicing and Filtering

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# # Slicing Columns

# %%
df["host_name"]
# Out:
# 0                 John
# 1             Jennifer
# 2            Elisabeth
# 3          LisaRoxanne
# 4                Laura
#              ...
# 48890          Sabrina
# 48891          Marisol
# 48892    Ilgar & Aysel
# 48893              Taz
# 48894       Christophe
# Name: host_name, Length: 48895, dtype: object

# %%
df.host_name
# Out:
# 0                 John
# 1             Jennifer
# 2            Elisabeth
# 3          LisaRoxanne
# 4                Laura
#              ...
# 48890          Sabrina
# 48891          Marisol
# 48892    Ilgar & Aysel
# 48893              Taz
# 48894       Christophe
# Name: host_name, Length: 48895, dtype: object

# %%
df[["host_name", "neighbourhood_group"]]
# Out:
#            host_name neighbourhood_group
# 0               John            Brooklyn
# 1           Jennifer           Manhattan
# 2          Elisabeth           Manhattan
# 3        LisaRoxanne            Brooklyn
# 4              Laura           Manhattan
# ...              ...                 ...
# 48890        Sabrina            Brooklyn
# 48891        Marisol            Brooklyn
# 48892  Ilgar & Aysel           Manhattan
# 48893            Taz           Manhattan
# 48894     Christophe           Manhattan
#
# [48895 rows x 2 columns]

# %% [markdown]
# # Filtering on rows (mask filtering)

# %%
df[df.host_name == "Taz"]
# Out:
#              id                                               name   host_id  \
# 31463  24491624           43rd Street=TIME SQUARE\nPRIVATE BEDROOM  30985759
# 31517  24539281             43rd Street “TIME SQUARE”\nSingle bed.  30985759
# 37598  29827403  “TIME SQUARE” 43rd Street\nBig Bedroom on 1st ...  30985759
# 37615  29831106  TIME SQUARE” 43rd street\nPrivate room on 1st ...  30985759
# 37795  29929331               “TIME SQUARE” 43rd street SINGLE BED  30985759
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
#
#       host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 31463       Taz           Manhattan  Hell's Kitchen  40.75780  -73.99211
# 31517       Taz           Manhattan  Hell's Kitchen  40.75792  -73.99172
# 37598       Taz           Manhattan  Hell's Kitchen  40.75988  -73.99123
# 37615       Taz           Manhattan  Hell's Kitchen  40.75938  -73.98986
# ...

# %%
df.host_name == "Taz"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893     True
# 48894    False
# Name: host_name, Length: 48895, dtype: bool

# %%
(df.host_name == "Taz").sum()
# Out:
# 6

# %%
# create a mask (filter) 
mask = df.host_name == "Taz"
df[mask].head(2)
# Out:
#              id                                      name   host_id host_name  \
# 31463  24491624  43rd Street=TIME SQUARE\nPRIVATE BEDROOM  30985759       Taz
# 31517  24539281    43rd Street “TIME SQUARE”\nSingle bed.  30985759       Taz
#
#       neighbourhood_group   neighbourhood  latitude  longitude     room_type  \
# 31463           Manhattan  Hell's Kitchen  40.75780  -73.99211  Private room
# 31517           Manhattan  Hell's Kitchen  40.75792  -73.99172   Shared room
#
#        price  minimum_nights  number_of_reviews last_review  \
# 31463    116               1                 95  2019-07-04
# 31517     65               1                108  2019-06-23
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 31463               6.42                               6               280
# 31517               7.33                               6               325

# %%
quick_and_cheap = (df.price < 100) & (df.minimum_nights < 3)
quick_and_cheap.sum()
# Out:
# 12129

# %%
df[quick_and_cheap].head(2)
# Out:
#      id                              name  host_id    host_name  \
# 3  3831   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 7  5178  Large Furnished Room Near B'way      8967     Shunichi
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 3            Brooklyn    Clinton Hill  40.68514  -73.95976  Entire home/apt
# 7           Manhattan  Hell's Kitchen  40.76489  -73.98493     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 3     89               1                270  2019-07-05               4.64
# 7     79               2                430  2019-06-24               3.47
#
#    calculated_host_listings_count  availability_365
# 3                               1               194
# 7                               1               220

# %%
reviews_consistent = df[(df.reviews_per_month > 3) | (df.number_of_reviews > 50)]
reviews_consistent.head(3)
# Out:
#      id                                       name  host_id    host_name  \
# 3  3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 7  5178           Large Furnished Room Near B'way      8967     Shunichi
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 3            Brooklyn    Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5           Manhattan     Murray Hill  40.74767  -73.97500  Entire home/apt
# 7           Manhattan  Hell's Kitchen  40.76489  -73.98493     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 3     89               1                270  2019-07-05               4.64
# 5    200               3                 74  2019-06-22               0.59
# 7     79               2                430  2019-06-24               3.47
#
#    calculated_host_listings_count  availability_365
# ...

# %%
mask = np.logical_or((df.reviews_per_month > 3), (df.number_of_reviews > 50))
df[mask].head(2)
# Out:
#      id                                       name  host_id    host_name  \
# 3  3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5           Manhattan   Murray Hill  40.74767  -73.97500  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 3     89               1                270  2019-07-05               4.64
# 5    200               3                 74  2019-06-22               0.59
#
#    calculated_host_listings_count  availability_365
# 3                               1               194
# 5                               1               129

# %%
# show the data not in mask
df[~mask].head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# # Filtering columns and rows together

# %%
# filtered and show name and host_name columns
df.loc[mask,["name","host_name"]]
# Out:
#                                               name      host_name
# 3                  Cozy Entire Floor of Brownstone    LisaRoxanne
# 5        Large Cozy 1 BR Apartment In Midtown East          Chris
# 7                 Large Furnished Room Near B'way        Shunichi
# 8               Cozy Clean Guest Room - Family Apt      MaryEllen
# 9               Cute & Cozy Lower East Side 1 bdrm            Ben
# ...                                            ...            ...
# 47848                Penn House~~~~5 mins from JFK           Penn
# 47967       Cosy Bedroom in the Heart of Manhattan         Dayana
# 48031  Large bedroom with private bathroom is suit  Alex And Mila
# 48228              1910 Original Rockaway Bungalow          Diana
# 48252               Cozy Apartment in Midtown West           Asil
#
# [9588 rows x 2 columns]

# %%
df.loc[mask, :].head()
# Out:
#      id                                       name  host_id    host_name  \
# 3  3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 7  5178           Large Furnished Room Near B'way      8967     Shunichi
# 8  5203         Cozy Clean Guest Room - Family Apt     7490    MaryEllen
# 9  5238         Cute & Cozy Lower East Side 1 bdrm     7549          Ben
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 3            Brooklyn     Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5           Manhattan      Murray Hill  40.74767  -73.97500  Entire home/apt
# 7           Manhattan   Hell's Kitchen  40.76489  -73.98493     Private room
# 8           Manhattan  Upper West Side  40.80178  -73.96723     Private room
# 9           Manhattan        Chinatown  40.71344  -73.99037  Entire home/apt
#
# ...

# %% [markdown]
# # Filtering based on Index?

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# show the value of [0(row-th),1(column-th)]
df.iloc[0,1]
# Out:
# 'Clean & quiet apt home by the park'

# %%
df2 = df.set_index("id")
df2.head(2)
# Out:
#                                     name  host_id host_name  \
# id
# 2539  Clean & quiet apt home by the park     2787      John
# 2595               Skylit Midtown Castle     2845  Jennifer
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# id
# 2539    149               1                  9  2018-10-19               0.21
# 2595    225               1                 45  2019-05-21               0.38
#
#       calculated_host_listings_count  availability_365
# id
# 2539                               6               365
# 2595                               2               355

# %%
# show the first row of data
df2.iloc[0,:]
# Out:
# name                              Clean & quiet apt home by the park
# host_id                                                         2787
# host_name                                                       John
# neighbourhood_group                                         Brooklyn
# neighbourhood                                             Kensington
# latitude                                                     40.6475
# longitude                                                   -73.9724
# room_type                                               Private room
# price                                                            149
# minimum_nights                                                     1
# number_of_reviews                                                  9
# last_review                                               2018-10-19
# reviews_per_month                                               0.21
# calculated_host_listings_count                                     6
# ...

# %%
df2.iloc[1:4, 6:]
# Out:
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# id
# 2595  -73.98377  Entire home/apt    225               1                 45
# 3647  -73.94190     Private room    150               3                  0
# 3831  -73.95976  Entire home/apt     89               1                270
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# id
# 2595  2019-05-21               0.38                               2
# 3647         NaN                NaN                               1
# 3831  2019-07-05               4.64                               1
#
#       availability_365
# id
# 2595               355
# 3647               365
# 3831               194

# %% [markdown]
# # Provided mask helpers

# %%
df.loc[df.price.between(100, 200), "price"].head()
# Out:
# 0     149
# 2     150
# 5     200
# 9     150
# 10    135
# Name: price, dtype: int64

# %%
df.loc[df.price.isin([100, 200]), "price"].head()
# Out:
# 5     200
# 54    200
# 63    200
# 76    200
# 94    100
# Name: price, dtype: int64

# %%
df == "John"
# Out:
# /Users/ycliu3/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False       True                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# ...

# %%
# show any column has a value of John
(df == "John").any()
# Out:
# /Users/ycliu3/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# id                                False
# name                              False
# host_id                           False
# host_name                          True
# neighbourhood_group               False
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# last_review                       False
# reviews_per_month                 False
# calculated_host_listings_count    False
# availability_365                  False
# dtype: bool

# %%
# show which row has John
(df == "John").any(axis=1)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Length: 48895, dtype: bool

# %% [markdown]
# # Views vs Copy

# %%
df2 = df.copy()
df2.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
# This is not a preferred way to modify the data
df2["name"][0] = "Testing"
df2.head(1)
# Out:
# /Users/ycliu3/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      id     name  host_id host_name neighbourhood_group neighbourhood  \
# 0  2539  Testing     2787      John            Brooklyn    Kensington
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 0  40.64749  -73.97237  Private room    149               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %%
# this is much more recommended
df.loc[df2.index==0, "name"] = "Testing"
df2.head(1)
# Out:
#      id     name  host_id host_name neighbourhood_group neighbourhood  \
# 0  2539  Testing     2787      John            Brooklyn    Kensington
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 0  40.64749  -73.97237  Private room    149               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %%
# Not recommended either
df2[df2.host_name == "John"]["name"] = "Oh no"
df2.head(1)
# Out:
# /Users/ycliu3/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      id     name  host_id host_name neighbourhood_group neighbourhood  \
# 0  2539  Testing     2787      John            Brooklyn    Kensington
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 0  40.64749  -73.97237  Private room    149               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %% [markdown]
# # Basics - Replacing and Thresholding

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# # Dealing with NaNs

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# display how many null values
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# drop the null values in last_review by row
df.dropna(subset=["last_review"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38843 entries, 0 to 48852
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38843 non-null  int64
#  1   name                            38837 non-null  object
#  2   host_id                         38843 non-null  int64
#  3   host_name                       38827 non-null  object
#  4   neighbourhood_group             38843 non-null  object
#  5   neighbourhood                   38843 non-null  object
#  6   latitude                        38843 non-null  float64
#  7   longitude                       38843 non-null  float64
#  8   room_type                       38843 non-null  object
#  9   price                           38843 non-null  int64
#  10  minimum_nights                  38843 non-null  int64
#  11  number_of_reviews               38843 non-null  int64
# ...

# %%
# fill null column with 0
df.fillna(0)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # Generic replace

# %%
# replace value with another value
df.replace("John", "Jono").head(1)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      Jono
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0            Brooklyn    Kensington  40.64749  -73.97237  Private room    149
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               1                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %%
# replace indicated column value
df.host_name.replace("John", "Jono", limit=1)[0]
# Out:
# 'Jono'

# %%
# replace multiple columns at once
df.replace({"John": "Jono", "Brooklyn": "Brooky"}).head(1)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      Jono
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0              Brooky    Kensington  40.64749  -73.97237  Private room    149
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               1                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %% [markdown]
# # Thresholding

# %%
# plot the pricing and see there are too spread out
plt.hist(df.price);

# %%
# set a maximum and all values above maximum would be counted in to maximum bin
plt.hist(df.price.clip(upper=1000));

# %%
# Compare to the previous chart, it should be same
df2 = df.copy()
df2.loc[df2.price > 1000, "price"] = 1000
plt.hist(df2.price);

# %% [markdown]
# # Basics - Removing and Adding Data

# %% [markdown]
# https://www.kaggle.com/nasa/astronaut-yearbook

# %%
df = pd.read_csv("astronauts.csv")
df.head(1)
# Out:
#               Name    Year  Group  Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0  Active  5/17/1967  Inglewood, CA   Male
#
#                                           Alma Mater Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...             Geology
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN

# %% [markdown]
# # Modifying Type of Columns

# %% [markdown]
# # Timeseries

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
# change Birth Date from object to datetime64
birthdate = pd.to_datetime(df["Birth Date"], format="%m/%d/%Y")
birthdate
# Out:
# 0     1967-05-17
# 1     1936-03-07
# 2     1946-03-03
# 3     1951-05-20
# 4     1930-01-20
#          ...
# 352   1956-08-23
# 353   1962-07-26
# 354   1932-02-07
# 355   1930-09-24
# 356   1962-06-29
# Name: Birth Date, Length: 357, dtype: datetime64[ns]

# %%
# also can look at by year/month/day
birthdate.dt.year
# Out:
# 0      1967
# 1      1936
# 2      1946
# 3      1951
# 4      1930
#        ...
# 352    1956
# 353    1962
# 354    1932
# 355    1930
# 356    1962
# Name: Birth Date, Length: 357, dtype: int64

# %%
# calculate between datetimes
zarya = pd.to_datetime("1998-11-20")
df["age_at_zarya"] = (zarya - birthdate).astype('timedelta64[Y]')
display(df[["Birth Date","age_at_zarya"]].head(), df[["Birth Date","age_at_zarya"]].dtypes)
# Out:
#   Birth Date  age_at_zarya
# 0  5/17/1967          31.0
# 1   3/7/1936          62.0
# 2   3/3/1946          52.0
# 3  5/20/1951          47.0
# 4  1/20/1930          68.0
# Birth Date       object
# age_at_zarya    float64
# dtype: object

# %%
df["birth"] = birthdate
df.head(3)
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
# 2          US Military Academy; Princeton University          Engineering
#
#           Graduate Major  ...    Military Branch Space Flights  \
# 0                Geology  ...                NaN             2
# 1          Solar Physics  ...                NaN             1
# 2  Aerospace Engineering  ...  US Army (Retired)             2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# ...

# %% [markdown]
# # Categoricals

# %% [markdown]
# Information can be utilised by other libraries that pandas interfaces with, you can provide explicit sorting order rathen than lexical order, and huge speed improvements if you group on categorie

# %%
df["Military Rank"].unique()
# Out:
# array([nan, 'Colonel', 'Lieutenant Colonel', 'Captain', 'Major General',
#        'Commander', 'Lieutenant Commander', 'Brigadier General', 'Major',
#        'Lieutenant General', 'Chief Warrant Officer', 'Rear Admiral',
#        'Vice Admiral'], dtype=object)

# %%
df["Military Rank"].dtype
# Out:
# dtype('O')

# %%
# change the column data type to category
df["Military Rank"] = df["Military Rank"].astype("category")
df["Military Rank"].dtype

# pd.Categorical(df["Military Rank"]) <-same
# Out:
# CategoricalDtype(categories=['Brigadier General', 'Captain', 'Chief Warrant Officer',
#                   'Colonel', 'Commander', 'Lieutenant Colonel',
#                   'Lieutenant Commander', 'Lieutenant General', 'Major',
#                   'Major General', 'Rear Admiral', 'Vice Admiral'],
#                  ordered=False)

# %% [markdown]
# # Numeric / String Conversion

# %%
df.age_at_zarya.dtype
# Out:
# dtype('float64')

# %%
# change the data type from float to integer
df.age_at_zarya.astype("str").astype("float").astype("int")[0]
# Out:
# 31

# %% [markdown]
# # Removing Columns or Rows

# %%
df2 = df[["Name", "Year", "Group"]].copy()
df2.head()
# Out:
#                Name    Year  Group
# 0   Joseph M. Acaba  2004.0   19.0
# 1    Loren W. Acton     NaN    NaN
# 2  James C. Adamson  1984.0   10.0
# 3   Thomas D. Akers  1987.0   12.0
# 4       Buzz Aldrin  1963.0    3.0

# %%
# drop an entire column
df2.drop("Group", axis=1).head()
# df2.drop(columns="Group").head() <-same
# Out:
#                Name    Year
# 0   Joseph M. Acaba  2004.0
# 1    Loren W. Acton     NaN
# 2  James C. Adamson  1984.0
# 3   Thomas D. Akers  1987.0
# 4       Buzz Aldrin  1963.0

# %%
# drop a row
df2.drop(1).head()
# Out:
#                Name    Year  Group
# 0   Joseph M. Acaba  2004.0   19.0
# 2  James C. Adamson  1984.0   10.0
# 3   Thomas D. Akers  1987.0   12.0
# 4       Buzz Aldrin  1963.0    3.0
# 5   Andrew M. Allen  1987.0   12.0

# %%
df2.drop(columns=["Year", "Group"]).head()
# Out:
#                Name
# 0   Joseph M. Acaba
# 1    Loren W. Acton
# 2  James C. Adamson
# 3   Thomas D. Akers
# 4       Buzz Aldrin

# %% [markdown]
# # Adding rows

# %%
df2.append({"Name": "Samuel Hinton", "Year": 2010, "Group": 20.0}, ignore_index=True)
# Out:
#                       Name    Year  Group
# 0          Joseph M. Acaba  2004.0   19.0
# 1           Loren W. Acton     NaN    NaN
# 2         James C. Adamson  1984.0   10.0
# 3          Thomas D. Akers  1987.0   12.0
# 4              Buzz Aldrin  1963.0    3.0
# ..                     ...     ...    ...
# 353  Neil W. Woodward III   1998.0   17.0
# 354       Alfred M. Worden  1966.0    5.0
# 355          John W. Young  1962.0    2.0
# 356        George D. Zamka  1998.0   17.0
# 357          Samuel Hinton  2010.0   20.0
#
# [358 rows x 3 columns]

# %%
df_sis = pd.DataFrame({"Name": ["Al Hinton"], "Year": [2010], "Group": [20.0]})
df_sis
# Out:
#         Name  Year  Group
# 0  Al Hinton  2010   20.0

# %%
df2.append(df_sis, ignore_index=True)
# Out:
#                       Name    Year  Group
# 0          Joseph M. Acaba  2004.0   19.0
# 1           Loren W. Acton     NaN    NaN
# 2         James C. Adamson  1984.0   10.0
# 3          Thomas D. Akers  1987.0   12.0
# 4              Buzz Aldrin  1963.0    3.0
# ..                     ...     ...    ...
# 353  Neil W. Woodward III   1998.0   17.0
# 354       Alfred M. Worden  1966.0    5.0
# 355          John W. Young  1962.0    2.0
# 356        George D. Zamka  1998.0   17.0
# 357              Al Hinton  2010.0   20.0
#
# [358 rows x 3 columns]

# %% [markdown]
# # Adding Columns

# %%
df2["Col1"] = "Whoa"
df2
# Out:
#                       Name    Year  Group  Col1
# 0          Joseph M. Acaba  2004.0   19.0  Whoa
# 1           Loren W. Acton     NaN    NaN  Whoa
# 2         James C. Adamson  1984.0   10.0  Whoa
# 3          Thomas D. Akers  1987.0   12.0  Whoa
# 4              Buzz Aldrin  1963.0    3.0  Whoa
# ..                     ...     ...    ...   ...
# 352          David A. Wolf  1990.0   13.0  Whoa
# 353  Neil W. Woodward III   1998.0   17.0  Whoa
# 354       Alfred M. Worden  1966.0    5.0  Whoa
# 355          John W. Young  1962.0    2.0  Whoa
# 356        George D. Zamka  1998.0   17.0  Whoa
#
# [357 rows x 4 columns]

# %%
df2.assign(some_col="someval")
# Out:
#                       Name    Year  Group  Col1 some_col
# 0          Joseph M. Acaba  2004.0   19.0  Whoa  someval
# 1           Loren W. Acton     NaN    NaN  Whoa  someval
# 2         James C. Adamson  1984.0   10.0  Whoa  someval
# 3          Thomas D. Akers  1987.0   12.0  Whoa  someval
# 4              Buzz Aldrin  1963.0    3.0  Whoa  someval
# ..                     ...     ...    ...   ...      ...
# 352          David A. Wolf  1990.0   13.0  Whoa  someval
# 353  Neil W. Woodward III   1998.0   17.0  Whoa  someval
# 354       Alfred M. Worden  1966.0    5.0  Whoa  someval
# 355          John W. Young  1962.0    2.0  Whoa  someval
# 356        George D. Zamka  1998.0   17.0  Whoa  someval
#
# [357 rows x 5 columns]

# %%
# insert first column 0, split the value by 1 space, and expand the column
df2.insert(0, "FirstName", df.Name.str.split(" ", 1, expand=True)[0])
df2.head()
# Out:
#   FirstName              Name    Year  Group  Col1
# 0    Joseph   Joseph M. Acaba  2004.0   19.0  Whoa
# 1     Loren    Loren W. Acton     NaN    NaN  Whoa
# 2     James  James C. Adamson  1984.0   10.0  Whoa
# 3    Thomas   Thomas D. Akers  1987.0   12.0  Whoa
# 4      Buzz       Buzz Aldrin  1963.0    3.0  Whoa

# %%
df3 = df.set_index("Name")
df3.head(2)
# Out:
#                    Year  Group   Status Birth Date    Birth Place Gender  \
# Name
# Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# Loren W. Acton      NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                                         Alma Mater  \
# Name
# Joseph M. Acaba  University of California-Santa Barbara; Univer...
# Loren W. Acton    Montana State University; University of Colorado
#
#                  Undergraduate Major Graduate Major Military Rank  \
# Name
# Joseph M. Acaba              Geology        Geology           NaN
# Loren W. Acton   Engineering Physics  Solar Physics           NaN
#
#                 Military Branch  Space Flights  Space Flight (hr)  \
# Name
# Joseph M. Acaba             NaN              2               3307
# Loren W. Acton              NaN              1                190
#
#                  Space Walks  Space Walks (hr)  \
# Name
# Joseph M. Acaba            2              13.0
# ...

# %%
df3.T
# Out:
# Name                                                   Joseph M. Acaba  \
# Year                                                              2004
# Group                                                               19
# Status                                                          Active
# Birth Date                                                   5/17/1967
# Birth Place                                              Inglewood, CA
# Gender                                                            Male
# Alma Mater           University of California-Santa Barbara; Univer...
# Undergraduate Major                                            Geology
# Graduate Major                                                 Geology
# Military Rank                                                      NaN
# Military Branch                                                    NaN
# Space Flights                                                        2
# ...

# %% [markdown]
# # Basics - Apply, Map and Vectorised Functions

# %%
import pandas as pd
import numpy as np

data = np.round(np.random.normal(size=(4, 3)), 2)
df = pd.DataFrame(data, columns=["A", "B", "C"])
df.head()
# Out:
#       A     B     C
# 0 -0.67 -0.16 -0.76
# 1  0.71  0.45  0.16
# 2 -0.39  1.89  0.11
# 3 -1.73  2.53  0.21

# %% [markdown]
# # Apply

# %%
# apply to all values
df.apply(lambda x: 1 + np.abs(x))
# Out:
#       A     B     C
# 0  1.67  1.16  1.76
# 1  1.71  1.45  1.16
# 2  1.39  2.89  1.11
# 3  2.73  3.53  1.21

# %%
# apply to a column
df.A.apply(np.abs)
# Out:
# 0    0.67
# 1    0.71
# 2    0.39
# 3    1.73
# Name: A, dtype: float64

# %%
# the below doesn't work
def double_if_positive(x):
    if x > 0:
        return 2 * x
    return x

df.apply(double_if_positive)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-f3703a253cb9> in <module>
#       5     return x
#       6
# ----> 7 df.apply(double_if_positive)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# ...

# %%
def double_if_positive(x):
    x[x>0] *=2
    return x

df.apply(double_if_positive)
# Out:
#       A     B     C
# 0 -0.67 -0.16 -0.76
# 1  1.42  0.90  0.32
# 2 -0.39  3.78  0.22
# 3 -1.73  5.06  0.42

# %%
# changed the originl data set
df
# Out:
#       A     B     C
# 0 -0.67 -0.16 -0.76
# 1  1.42  0.90  0.32
# 2 -0.39  3.78  0.22
# 3 -1.73  5.06  0.42

# %%
def double_if_positive(x):
    x = x.copy() # to avoid changing the original dataframe
    x[x > 0] *= 2
    return x

df.apply(double_if_positive, raw=True) # raw = true helps performance
# Out:
#       A      B     C
# 0 -0.67  -0.16 -0.76
# 1  2.84   1.80  0.64
# 2 -0.39   7.56  0.44
# 3 -1.73  10.12  0.84

# %%
df
# Out:
#       A     B     C
# 0 -0.67 -0.16 -0.76
# 1  1.42  0.90  0.32
# 2 -0.39  3.78  0.22
# 3 -1.73  5.06  0.42

# %% [markdown]
# # Map

# %%
series = pd.Series(["Steve", "Alex", "Jess", "Mark"])

# %%
series.map({"Steve": "Stephen"})
# Out:
# 0    Stephen
# 1        NaN
# 2        NaN
# 3        NaN
# dtype: object

# %%
series.map(lambda d: f"I am {d}")
# Out:
# 0    I am Steve
# 1     I am Alex
# 2     I am Jess
# 3     I am Mark
# dtype: object

# %% [markdown]
# # Vectorised functions

# %%
display(df, df.abs())
# Out:
#       A     B     C
# 0 -0.67 -0.16 -0.76
# 1  1.42  0.90  0.32
# 2 -0.39  3.78  0.22
# 3 -1.73  5.06  0.42
#       A     B     C
# 0  0.67  0.16  0.76
# 1  1.42  0.90  0.32
# 2  0.39  3.78  0.22
# 3  1.73  5.06  0.42

# %%
series = pd.Series(["Obi-Wan Kenobi", "Luke Skywalker", "Han Solo", "Leia Organa"])

# %%
"Luke Skywalker".split()
# Out:
# ['Luke', 'Skywalker']

# %%
# split data series
series.str.split(expand=True)
# Out:
#          0          1
# 0  Obi-Wan     Kenobi
# 1     Luke  Skywalker
# 2      Han       Solo
# 3     Leia     Organa

# %%
# identify any values contain certain words
series.str.contains("Skywalker")
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
# capitalize the data series and split it
series.str.upper().str.split()
# Out:
# 0    [OBI-WAN, KENOBI]
# 1    [LUKE, SKYWALKER]
# 2          [HAN, SOLO]
# 3       [LEIA, ORGANA]
# dtype: object

# %% [markdown]
# # User Defined Functions

# %%
data2 = np.random.normal(10, 2, size=(100000, 2))
df2 = pd.DataFrame(data2, columns=["x", "y"])
df2
# Out:
#                x          y
# 0       6.280145  11.550904
# 1      13.230826  12.681343
# 2      11.523798   9.657621
# 3       9.937865   9.900716
# 4      10.840153   6.917139
# ...          ...        ...
# 99995  12.200210  10.291310
# 99996  10.122385   8.623011
# 99997  10.789384   7.815621
# 99998   8.010306  13.413801
# 99999  12.014781   7.847393
#
# [100000 rows x 2 columns]

# %%
hypot = (df2.x**2 + df2.y**2)**0.5
print(hypot[0])
# Out:
# 13.147760164172265

# %%
# Not recommmended
def hypot1(x, y):
    return np.sqrt(x**2 + y**2)

h1 = []
for index, (x, y) in df2.iterrows():
    h1.append(hypot1(x, y))
print(h1[0])
# Out:
# 13.147760164172265

# %%
# Not recommended
def hypot2(row):
    return np.sqrt(row.x**2 + row.y**2)

h2 = df2.apply(hypot2, axis=1)
print(h2[0])
# Out:
# 13.147760164172265

# %%
def hypot3(xs, ys):
    return np.sqrt(xs**2 + ys**2)
h3 = hypot3(df2.x, df2.y)
print(h3[0])
# Out:
# 13.147760164172265

# %% [markdown]
# Vectorising everything you can is the key to speeding up your code. Once you've done that, you should use other tools to investigate. PyCharm Professional has a great optimisation tool built in. Jupyter has %lprun (line profiler) command you can find here: https://github.com/rkern/line_profiler

# %% [markdown]
# # Introduction to Grouping

# %%
df = pd.read_csv("train.csv", low_memory=False,parse_dates=["Date"])
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 69.8+ MB

# %%
dfg = df.groupby("Store")

# %%
store_avg = dfg.mean()
store_avg.head()
# Out:
#        DayOfWeek        Sales    Customers      Open     Promo  SchoolHoliday
# Store
# 1       3.997877  3945.704883   467.646497  0.829087  0.382166       0.204883
# 2       3.997877  4122.991507   486.045648  0.832272  0.382166       0.177282
# 3       3.997877  5741.253715   620.286624  0.826964  0.382166       0.180467
# 4       3.997877  8021.769639  1100.057325  0.832272  0.382166       0.183652
# 5       3.997877  3867.110403   444.360934  0.826964  0.382166       0.182590

# %%
store_avg = store_avg.reset_index()
store_avg.head()
# Out:
#    Store  DayOfWeek        Sales    Customers      Open     Promo  \
# 0      1   3.997877  3945.704883   467.646497  0.829087  0.382166
# 1      2   3.997877  4122.991507   486.045648  0.832272  0.382166
# 2      3   3.997877  5741.253715   620.286624  0.826964  0.382166
# 3      4   3.997877  8021.769639  1100.057325  0.832272  0.382166
# 4      5   3.997877  3867.110403   444.360934  0.826964  0.382166
#
#    SchoolHoliday
# 0       0.204883
# 1       0.177282
# 2       0.180467
# 3       0.183652
# 4       0.182590

# %%
store_avg.plot.scatter("Store","Sales",s=3,title="Avg sale per store")

# %% [markdown]
# # Multiple Groups

# %%
store_day = df.groupby(["Store", "DayOfWeek"], as_index=False).mean()
store_day.head()
# Out:
#    Store  DayOfWeek        Sales   Customers      Open     Promo  \
# 0      1          1  4946.119403  567.768657  0.955224  0.537313
# 1      1          2  4650.918519  545.370370  0.992593  0.533333
# 2      1          3  4454.474074  530.407407  0.977778  0.533333
# 3      1          4  4094.607407  493.407407  0.918519  0.533333
# 4      1          5  4516.414815  537.259259  0.955556  0.533333
#
#    SchoolHoliday
# 0       0.223881
# 1       0.229630
# 2       0.229630
# 3       0.222222
# 4       0.229630

# %%
for store in df.Store.unique()[:5]:
    df_tmp = store_day[store_day.Store == store]
    plt.plot(df_tmp.DayOfWeek, df_tmp.Sales, label=f"Store {store}")
plt.xlabel("Day of Week")
plt.ylabel("Avg Sales")
plt.legend();

# %% [markdown]
# # Continuous Grouping

# %%
df.groupby("Sales").mean().shape
# Out:
# (21734, 6)

# %%
df.Sales.describe()
# Out:
# count    1.017209e+06
# mean     5.773819e+03
# std      3.849926e+03
# min      0.000000e+00
# 25%      3.727000e+03
# 50%      5.744000e+03
# 75%      7.856000e+03
# max      4.155100e+04
# Name: Sales, dtype: float64

# %%
# set the range of bins
bins = [0, 2000, 4000, 6000, 8000, 10000, 50000]

# %%
# cut the values by the range bins
cuts = pd.cut(df.Sales, bins, include_lowest=True)
df["SalesGroup"] = cuts
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday          SalesGroup
# 0              1    (4000.0, 6000.0]
# 1              1    (6000.0, 8000.0]
# 2              1   (8000.0, 10000.0]
# 3              1  (10000.0, 50000.0]
# 4              1    (4000.0, 6000.0]

# %%
df.groupby(["Store", "SalesGroup"]).DayOfWeek.value_counts()
# Out:
# Store  SalesGroup          DayOfWeek
# 1      (-0.001, 2000.0]    7            134
#                            4             11
#                            1              6
#                            5              6
#                            3              3
#                                        ...
# 1115   (10000.0, 50000.0]  5              7
#                            2              2
#                            4              2
#                            6              2
#                            3              1
# Name: DayOfWeek, Length: 33024, dtype: int64

# %%
df.groupby(["Store", "SalesGroup"]).DayOfWeek.value_counts().unstack(fill_value=0)
# Out:
# DayOfWeek                  1   2   3   4   5    6    7
# Store SalesGroup
# 1     (-0.001, 2000.0]     6   1   3  11   6    0  134
#       (2000.0, 4000.0]    28  42  42  43  28   13    0
#       (4000.0, 6000.0]    70  80  83  72  91  109    0
#       (6000.0, 8000.0]    26  12   7   9   9   10    0
#       (8000.0, 10000.0]    4   0   0   0   1    2    0
# ...                       ..  ..  ..  ..  ..  ...  ...
# 1115  (2000.0, 4000.0]    15  17  15   9   0    0    0
#       (4000.0, 6000.0]    34  54  65  64  61   36    0
#       (6000.0, 8000.0]    30  52  39  39  50   80    0
#       (8000.0, 10000.0]   37   9  12  10  11   16    0
#       (10000.0, 50000.0]  12   2   1   2   7    2    0
#
# [6263 rows x 7 columns]

# %%
df.groupby(["Store", "SalesGroup", "DayOfWeek"]).Sales.count()
# Out:
# Store  SalesGroup          DayOfWeek
# 1      (-0.001, 2000.0]    1             6
#                            2             1
#                            3             3
#                            4            11
#                            5             6
#                                         ..
# 1115   (10000.0, 50000.0]  3             1
#                            4             2
#                            5             7
#                            6             2
#                            7             0
# Name: Sales, Length: 46830, dtype: int64

# %% [markdown]
# # Grouping - Imputation

# %% [markdown]
# https://www.kaggle.com/c/rossmann-store-sales/data

# %%
dfo = pd.read_csv("train.csv", low_memory=False, parse_dates=["Date"])
dfo.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
plt.hist(dfo.Sales);

# %%
df = dfo[dfo.Open == 1].copy()
plt.hist(df.Sales)
print(df.shape);
# Out:
# (844392, 9)

# %%
mask = np.random.choice(10, size=df.shape[0]) == 0 # random generate 844392 numbers in 10
df["NewSales"] = df.Sales.copy()
df.loc[mask, "NewSales"] = np.nan

plt.hist(df.Sales, label="Original", histtype="step")
plt.hist(df.NewSales.fillna(0), label="Corrupted", histtype="step")
plt.legend(), plt.xlabel("Sales");

# %%
(np.random.choice(10, size=df.shape[0]) == 0).sum()
# Out:
# 84277

# %%
# it doesn't look great
test_fix = df.NewSales.transform(lambda x: x.fillna(x.mean()))
plt.hist(test_fix, bins=100);

# %%
# Use median
dfg = df.groupby(["Store", "DayOfWeek"])
dfg.median().head()
# Out:
#                   Sales  Customers  Open  Promo  SchoolHoliday  NewSales
# Store DayOfWeek
# 1     1          5302.5      581.0   1.0    1.0            0.0    5280.0
#       2          4640.5      549.5   1.0    1.0            0.0    4678.0
#       3          4549.5      533.0   1.0    1.0            0.0    4561.5
#       4          4380.0      525.0   1.0    1.0            0.0    4395.0
#       5          4651.0      552.0   1.0    1.0            0.0    4609.0

# %%
test_fix2 = dfg.NewSales.transform(lambda x: x.fillna(x.mean()))

opts = {"histtype": "step", "bins": 50}
plt.hist(df.Sales, label="Original", **opts)
plt.hist(test_fix, label="Naive Fix", **opts)
plt.hist(test_fix2, label="This fix", **opts)
plt.legend(), plt.xlabel("Sales");

# %% [markdown]
# Now to utilise `transform` above again, this time on the group! Unlike apply or similar functions, transform requires that the output size is the same as in the input. So no condensing down numbers. You can think of it like aggregating to get a single number, but then backfilling it according to the correct group.

# %% [markdown]
# # Grouping - Aggregation

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("train.csv", low_memory=False, parse_dates=["Date"])  
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# # Single aggregates

# %%
df.groupby("Store").mean().head()
# Out:
#        DayOfWeek        Sales    Customers      Open     Promo  SchoolHoliday
# Store
# 1       3.997877  3945.704883   467.646497  0.829087  0.382166       0.204883
# 2       3.997877  4122.991507   486.045648  0.832272  0.382166       0.177282
# 3       3.997877  5741.253715   620.286624  0.826964  0.382166       0.180467
# 4       3.997877  8021.769639  1100.057325  0.832272  0.382166       0.183652
# 5       3.997877  3867.110403   444.360934  0.826964  0.382166       0.182590

# %% [markdown]
# # Different Aggregates for Different Columns

# %%
df.groupby(["Store", "DayOfWeek"]).agg({"Sales": "mean", "Customers": "count"})
# Out:
#                        Sales  Customers
# Store DayOfWeek
# 1     1          4946.119403        134
#       2          4650.918519        135
#       3          4454.474074        135
#       4          4094.607407        135
#       5          4516.414815        135
# ...                      ...        ...
# 1115  3          5666.155556        135
#       4          5396.607407        135
#       5          6208.881481        135
#       6          6773.388060        134
#       7             0.000000        134
#
# [7805 rows x 2 columns]

# %%
df2 = df.groupby(["Store", "DayOfWeek"]).agg({"Sales": ["mean", "max", "min"], "Customers": "count"})
df2.head()
# Out:
#                        Sales           Customers
#                         mean   max min     count
# Store DayOfWeek
# 1     1          4946.119403  9528   0       134
#       2          4650.918519  7959   0       135
#       3          4454.474074  7821   0       135
#       4          4094.607407  7785   0       135
#       5          4516.414815  8414   0       135

# %%
df2.columns = ["SalesMean", "SalesMax", "SalesMin", "Count"]
df2.head()
# Out:
#                    SalesMean  SalesMax  SalesMin  Count
# Store DayOfWeek
# 1     1          4946.119403      9528         0    134
#       2          4650.918519      7959         0    135
#       3          4454.474074      7821         0    135
#       4          4094.607407      7785         0    135
#       5          4516.414815      8414         0    135

# %%
# not recommended
mc_uncert = lambda x: np.std(x) / np.sqrt(x.size)
df2 = df.groupby(["Store", "DayOfWeek"]).agg(
    {"Sales": [("SalesMean", "mean"), ("SalesUncert", mc_uncert)], "Customers": "count"})
df2.head()
# Out:
#                        Sales             Customers
#                    SalesMean SalesUncert     count
# Store DayOfWeek
# 1     1          4946.119403  139.120367       134
#       2          4650.918519   94.412423       135
#       3          4454.474074   97.225056       135
#       4          4094.607407  129.367657       135
#       5          4516.414815  113.495466       135

# %%
# recommended
def mc_uncert2(x):
    return np.std(x) / np.sqrt(x.size)

dfg = df.groupby(["Store", "DayOfWeek"])
dfg.agg(
    SalesMean=("Sales", "mean"),
    SalesUncert=("Sales", mc_uncert2)
).reset_index().head()
# Out:
#    Store  DayOfWeek    SalesMean  SalesUncert
# 0      1          1  4946.119403   139.120367
# 1      1          2  4650.918519    94.412423
# 2      1          3  4454.474074    97.225056
# 3      1          4  4094.607407   129.367657
# 4      1          5  4516.414815   113.495466

# %% [markdown]
# # Merging Datasets
#
# http://tiny.cc/studcsv

# %%
import pandas as pd

students = pd.read_csv("students.csv")
teachers = pd.read_csv("teachers.csv")
grades1 = pd.read_csv("grades1.csv")
grades2 = pd.read_csv("grades2.csv")
contacts = pd.read_csv("contact.csv")

display(students.head(2),teachers.head(2),grades1.head(2),
       grades2.head(2),contacts.head(2))
# Out:
#       id firstname lastname
# 0  34292    Joshua    Davis
# 1  34293     Karen   Flores
#     course        teacher
# 0  PHYS101   Wayne Walker
# 1  CHEM101  Albert Taylor
#    student_id   course grade
# 0       34292  ENGL101     A
# 1       34293  ENGL101     A
#    student_id   course grade
# 0       34302  DRAM101     F
# 1       34303  DRAM101     D
#    student_id parent_contact           phone
# 0       34292   Samuel Davis  (356) 849-0352
# 1       34293   Laura Flores  (477) 325-7117

# %% [markdown]
# # Concat and append

# %%
grades1["Semester"] = 1
grades2["Semester"] = 2

# combines the selected dataframe
grades = pd.concat([grades1, grades2])
grades
# same as
# grades1.copy().append(grades2)
# Out:
#     student_id   course grade  Semester
# 0        34292  ENGL101     A         1
# 1        34293  ENGL101     A         1
# 2        34294  ENGL101     C         1
# 3        34295  ENGL101     C         1
# 4        34296  ENGL101     C         1
# ..         ...      ...   ...       ...
# 60       34312  DESN101     E         2
# 61       34313  DESN101     D         2
# 62       34314  DESN101     A         2
# 63       34315  DESN101     A         2
# 64       34316  DESN101     A         2
#
# [190 rows x 4 columns]

# %%
# but there is an issue that the index still contans the same after combination
# let's reindex the dataframe
grades = grades.reset_index(drop=True)
grades
# Out:
#      student_id   course grade  Semester
# 0         34292  ENGL101     A         1
# 1         34293  ENGL101     A         1
# 2         34294  ENGL101     C         1
# 3         34295  ENGL101     C         1
# 4         34296  ENGL101     C         1
# ..          ...      ...   ...       ...
# 185       34312  DESN101     E         2
# 186       34313  DESN101     D         2
# 187       34314  DESN101     A         2
# 188       34315  DESN101     A         2
# 189       34316  DESN101     A         2
#
# [190 rows x 4 columns]

# %% [markdown]
# # Mergin horizontally

# %%
student_grades = pd.merge(students, grades, left_on="id", right_on="student_id")
student_grades
# Out:
#         id firstname  lastname  student_id   course grade  Semester
# 0    34292    Joshua     Davis       34292  ENGL101     A         1
# 1    34292    Joshua     Davis       34292  MATH101     A         1
# 2    34292    Joshua     Davis       34292  PHYS101     D         1
# 3    34292    Joshua     Davis       34292  MATH102     F         1
# 4    34292    Joshua     Davis       34292  COMP101     A         1
# ..     ...       ...       ...         ...      ...   ...       ...
# 185  34316   Stephen  Martinez       34316  ARTT101     A         1
# 186  34316   Stephen  Martinez       34316  DESN101     A         1
# 187  34316   Stephen  Martinez       34316  DRAM101     F         2
# 188  34316   Stephen  Martinez       34316  ARTT101     A         2
# 189  34316   Stephen  Martinez       34316  DESN101     A         2
#
# [190 rows x 7 columns]

# %%
# double check if the combination is correct
print(students.shape, grades.shape, student_grades.shape)
# Out:
# (25, 3) (190, 4) (190, 7)

# %%
# rename the student's id column to student_id
students2 = students.rename({"id": "student_id"}, axis=1)
# because the selected merge columns have same column name, no need to add right_on/left_on
students_full = students2.merge(contacts, on="student_id")
students_full.head()
# Out:
#    student_id firstname  lastname  parent_contact           phone
# 0       34292    Joshua     Davis    Samuel Davis  (356) 849-0352
# 1       34293     Karen    Flores    Laura Flores  (477) 325-7117
# 2       34294     Julia    Walker     Eric Walker  (871) 639-0797
# 3       34295   Cynthia  Robinson  Chris Robinson  (574) 683-2107
# 4       34296    Bonnie      Hall    Dorothy Hall  (384) 293-2113

# %%
student_grades = pd.merge(students2, grades, on="student_id")
df = pd.merge(student_grades, contacts, on="student_id")
df.head()
# Out:
#    student_id firstname lastname   course grade  Semester parent_contact  \
# 0       34292    Joshua    Davis  ENGL101     A         1   Samuel Davis
# 1       34292    Joshua    Davis  MATH101     A         1   Samuel Davis
# 2       34292    Joshua    Davis  PHYS101     D         1   Samuel Davis
# 3       34292    Joshua    Davis  MATH102     F         1   Samuel Davis
# 4       34292    Joshua    Davis  COMP101     A         1   Samuel Davis
#
#             phone
# 0  (356) 849-0352
# 1  (356) 849-0352
# 2  (356) 849-0352
# 3  (356) 849-0352
# 4  (356) 849-0352

# %%
df = df.merge(teachers, on="course")
df.head()
# Out:
#    student_id firstname  lastname   course grade  Semester  parent_contact  \
# 0       34292    Joshua     Davis  ENGL101     A         1    Samuel Davis
# 1       34293     Karen    Flores  ENGL101     A         1    Laura Flores
# 2       34294     Julia    Walker  ENGL101     C         1     Eric Walker
# 3       34295   Cynthia  Robinson  ENGL101     C         1  Chris Robinson
# 4       34296    Bonnie      Hall  ENGL101     C         1    Dorothy Hall
#
#             phone       teacher
# 0  (356) 849-0352  Ernest Green
# 1  (477) 325-7117  Ernest Green
# 2  (871) 639-0797  Ernest Green
# 3  (574) 683-2107  Ernest Green
# 4  (384) 293-2113  Ernest Green

# %%
# count how many people failed by F
df2 = df.loc[df.grade == "F", "student_id"]
method1 = df2.value_counts().rename_axis("student_id").reset_index(name="counts")
method1
# Out:
#     student_id  counts
# 0        34300       4
# 1        34302       3
# 2        34303       2
# 3        34309       2
# 4        34311       2
# 5        34313       2
# 6        34316       2
# 7        34292       2
# 8        34294       2
# 9        34299       2
# 10       34301       2
# 11       34304       2
# 12       34293       1
# 13       34297       1
# 14       34314       1
# 15       34298       1
# 16       34310       1
# 17       34306       1

# %%
method2 = df.loc[df.grade == "F", ["student_id", "grade"]].groupby("student_id").count().reset_index()
method2.columns = ["student_id", "counts"]
method2
# Out:
#     student_id  counts
# 0        34292       2
# 1        34293       1
# 2        34294       2
# 3        34297       1
# 4        34298       1
# 5        34299       2
# 6        34300       4
# 7        34301       2
# 8        34302       3
# 9        34303       2
# 10       34304       2
# 11       34306       1
# 12       34309       2
# 13       34310       1
# 14       34311       2
# 15       34313       2
# 16       34314       1
# 17       34316       2

# %%
# See who failed at least 3 subjects
sids = method1[method1.counts >= 3].student_id
sids.head()
# Out:
# 0    34300
# 1    34302
# Name: student_id, dtype: int64

# %%
final = students_full[students_full.student_id.isin(sids)]
final
# Out:
#     student_id firstname  lastname   parent_contact           phone
# 8        34300      Mary  Mitchell  Edward Mitchell  (494) 471-1604
# 10       34302   Dorothy     Green    Russell Green  (749) 344-5744

# %% [markdown]
# # Join

# %%
display(students.head(),contacts.head())
# Out:
#       id firstname  lastname
# 0  34292    Joshua     Davis
# 1  34293     Karen    Flores
# 2  34294     Julia    Walker
# 3  34295   Cynthia  Robinson
# 4  34296    Bonnie      Hall
#    student_id  parent_contact           phone
# 0       34292    Samuel Davis  (356) 849-0352
# 1       34293    Laura Flores  (477) 325-7117
# 2       34294     Eric Walker  (871) 639-0797
# 3       34295  Chris Robinson  (574) 683-2107
# 4       34296    Dorothy Hall  (384) 293-2113

# %%
# set the columns to be index then we can use join
students2 = students.set_index("id")
contacts2 = contacts.set_index("student_id")

students2.join(contacts2)
# Out:
#       firstname  lastname   parent_contact           phone
# id
# 34292    Joshua     Davis     Samuel Davis  (356) 849-0352
# 34293     Karen    Flores     Laura Flores  (477) 325-7117
# 34294     Julia    Walker      Eric Walker  (871) 639-0797
# 34295   Cynthia  Robinson   Chris Robinson  (574) 683-2107
# 34296    Bonnie      Hall     Dorothy Hall  (384) 293-2113
# 34297  Gary Lee       Lee         Mary Lee  (914) 452-6366
# 34298      Ruby  Thompson    Jose Thompson  (253) 419-7702
# 34299   Heather    Miller     Annie Miller  (864) 583-9615
# 34300      Mary  Mitchell  Edward Mitchell  (494) 471-1604
# 34301    Carlos      Ross       Debra Ross  (592) 663-4425
# 34302   Dorothy     Green    Russell Green  (749) 344-5744
# 34303      Joan      Wood      Walter Wood  (457) 429-8627
# 34304      Judy     Jones       Lisa Jones  (773) 266-0693
# 34305     Nancy    Turner   Barbara Turner  (908) 350-9105
# 34306      Mark  Phillips  Jeremy Phillips  (600) 628-1550
# ...

# %% [markdown]
# # Merging Types

# %%
import pandas as pd

df_s = pd.read_csv("students.csv")
df_p = pd.read_csv("contact.csv")
df_g = pd.read_csv("grades1.csv")

# %%
df_g.tail()
# Out:
#      student_id   course grade
# 120       34312  DESN101     E
# 121       34313  DESN101     D
# 122       34314  DESN101     A
# 123       34315  DESN101     A
# 124       34316  DESN101     A

# %%
df_desn = df_g[df_g.course == "DESN101"]
print(df_desn.shape, df_s.shape)
# So we have 25 students, but only 12 of them took design 101.
# df_desn is (12,3)
# df_s is (25, 3)
# Out:
# (12, 3) (25, 3)

# %% [markdown]
# # Merge Types

# %%
# inner join (by default)
pd.merge(df_s, df_desn, left_on="id", right_on="student_id")
# same as 
# pd.merge(df_s, df_desn, left_on="id", right_on="student_id", how="inner")
# Out:
#        id firstname  lastname  student_id   course grade
# 0   34295   Cynthia  Robinson       34295  DESN101     C
# 1   34296    Bonnie      Hall       34296  DESN101     C
# 2   34297  Gary Lee       Lee       34297  DESN101     A
# 3   34308     Shawn    Rivera       34308  DESN101     E
# 4   34309      Lois     James       34309  DESN101     B
# 5   34310   William   Sanders       34310  DESN101     C
# 6   34311   Barbara  Peterson       34311  DESN101     D
# 7   34312   Douglas      Cook       34312  DESN101     E
# 8   34313     Helen     Allen       34313  DESN101     D
# 9   34314   Melissa     Price       34314  DESN101     A
# 10  34315   Russell      Reed       34315  DESN101     A
# 11  34316   Stephen  Martinez       34316  DESN101     A

# %%
# left join
pd.merge(df_s, df_desn, left_on="id", right_on="student_id", how="left")
# Out:
#        id firstname  lastname  student_id   course grade
# 0   34292    Joshua     Davis         NaN      NaN   NaN
# 1   34293     Karen    Flores         NaN      NaN   NaN
# 2   34294     Julia    Walker         NaN      NaN   NaN
# 3   34295   Cynthia  Robinson     34295.0  DESN101     C
# 4   34296    Bonnie      Hall     34296.0  DESN101     C
# 5   34297  Gary Lee       Lee     34297.0  DESN101     A
# 6   34298      Ruby  Thompson         NaN      NaN   NaN
# 7   34299   Heather    Miller         NaN      NaN   NaN
# 8   34300      Mary  Mitchell         NaN      NaN   NaN
# 9   34301    Carlos      Ross         NaN      NaN   NaN
# 10  34302   Dorothy     Green         NaN      NaN   NaN
# 11  34303      Joan      Wood         NaN      NaN   NaN
# 12  34304      Judy     Jones         NaN      NaN   NaN
# 13  34305     Nancy    Turner         NaN      NaN   NaN
# 14  34306      Mark  Phillips         NaN      NaN   NaN
# ...

# %%
# create new dataframe
df_a = pd.DataFrame({"A": ["x", "y", "z"], "B": [1, 2, 3]})
df_b = pd.DataFrame({"A": ["u", "v", "x"], "C": [5.0, 4.0, 3.0]})

display(df_a, df_b);
# Out:
#    A  B
# 0  x  1
# 1  y  2
# 2  z  3
#    A    C
# 0  u  5.0
# 1  v  4.0
# 2  x  3.0

# %%
# inner join
pd.merge(df_a, df_b, on="A")
# Out:
#    A  B    C
# 0  x  1  3.0

# %%
# outer join
pd.merge(df_a, df_b, on="A", how="outer")
# Out:
#    A    B    C
# 0  x  1.0  3.0
# 1  y  2.0  NaN
# 2  z  3.0  NaN
# 3  u  NaN  5.0
# 4  v  NaN  4.0

# %% [markdown]
# # Duplicate keys

# %%
df_c = pd.DataFrame({"A":["x","x","z"], "B":[1,2,3]})
df_d = pd.DataFrame({"A": ["u", "x", "x"], "C": [5.0, 4.0, 3.0]})

display(df_c, df_d);
# Out:
#    A  B
# 0  x  1
# 1  x  2
# 2  z  3
#    A    C
# 0  u  5.0
# 1  x  4.0
# 2  x  3.0

# %%
pd.merge(df_c, df_d, on="A")
# Out:
#    A  B    C
# 0  x  1  4.0
# 1  x  1  3.0
# 2  x  2  4.0
# 3  x  2  3.0

# %% [markdown]
# # Duplicate Columns

# %%
df_e = pd.DataFrame({"A": ["x", "y", "z"], "B": [1, 2, 3]})
df_f = pd.DataFrame({"A": ["u", "v", "x"], "B": [5.0, 4.0, 3.0]})

display(df_e, df_f)
# Out:
#    A  B
# 0  x  1
# 1  y  2
# 2  z  3
#    A    B
# 0  u  5.0
# 1  v  4.0
# 2  x  3.0

# %%
pd.merge(df_e, df_f, on="A")
# Out:
#    A  B_x  B_y
# 0  x    1  3.0

# %%
df_m = pd.merge(df_e, df_f, on="A", suffixes=("_left", "_right"))
df_m
# Out:
#    A  B_left  B_right
# 0  x       1      3.0

# %%
df_m.rename(columns={"B_left":"Hello","B_right":"General Kernobl"})
# Out:
#    A  Hello  General Kernobl
# 0  x      1              3.0

# %% [markdown]
# # Validating Expected Outputs

# %%
display(df_s.head(2),df_p.head(2)), df_s.shape, df_p.shape
# Out:
#       id firstname lastname
# 0  34292    Joshua    Davis
# 1  34293     Karen   Flores
#    student_id parent_contact           phone
# 0       34292   Samuel Davis  (356) 849-0352
# 1       34293   Laura Flores  (477) 325-7117
# (None, (25, 3), (25, 3))

# %%
# expect all students to have a contact. We dont have to do shape checks to validate this.
pd.merge(df_s, df_p, left_on="id", right_on="student_id", validate="one_to_one")
# same as
# df_p2 = df_p.append(df_p.iloc[0])
# pd.merge(df_s, df_p2, left_on="id", right_on="student_id", validate="one_to_many")
# Out:
#        id firstname  lastname  student_id   parent_contact           phone
# 0   34292    Joshua     Davis       34292     Samuel Davis  (356) 849-0352
# 1   34293     Karen    Flores       34293     Laura Flores  (477) 325-7117
# 2   34294     Julia    Walker       34294      Eric Walker  (871) 639-0797
# 3   34295   Cynthia  Robinson       34295   Chris Robinson  (574) 683-2107
# 4   34296    Bonnie      Hall       34296     Dorothy Hall  (384) 293-2113
# 5   34297  Gary Lee       Lee       34297         Mary Lee  (914) 452-6366
# 6   34298      Ruby  Thompson       34298    Jose Thompson  (253) 419-7702
# 7   34299   Heather    Miller       34299     Annie Miller  (864) 583-9615
# 8   34300      Mary  Mitchell       34300  Edward Mitchell  (494) 471-1604
# 9   34301    Carlos      Ross       34301       Debra Ross  (592) 663-4425
# 10  34302   Dorothy     Green       34302    Russell Green  (749) 344-5744
# ...

# %% [markdown]
# # Composite Keys

# %%
df_1 = pd.DataFrame({"year": [2000, 2000, 2001, 2001], "sem": [1, 2, 1, 2], 
                     "fee": [200, 200, 200, 200]})
df_2 = pd.DataFrame({"year": [2000, 2000, 2001, 2001], "sem": [1, 2, 1, 2], 
                     "student": [1, 2, 2, 3], "discount": [0.1, 0.2, 0.2, 1.0]})
df_3 = pd.DataFrame({"student": [1, 2, 3, 4, 5]})

display(df_1, df_2, df_3)
from IPython.display import Javascript
Javascript('this.element.attr("style", "flex-direction: row;")')
# Out:
#    year  sem  fee
# 0  2000    1  200
# 1  2000    2  200
# 2  2001    1  200
# 3  2001    2  200
#    year  sem  student  discount
# 0  2000    1        1       0.1
# 1  2000    2        2       0.2
# 2  2001    1        2       0.2
# 3  2001    2        3       1.0
#    student
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
combined = pd.merge(df_1, df_2, on=["year", "sem"])
combined["due"] = combined.fee * (1 - combined.discount)
combined
# Out:
#    year  sem  fee  student  discount    due
# 0  2000    1  200        1       0.1  180.0
# 1  2000    2  200        2       0.2  160.0
# 2  2001    1  200        2       0.2  160.0
# 3  2001    2  200        3       1.0    0.0

# %%
pd.merge(df_3, df_2, on="student", how="left")
# Out:
#    student    year  sem  discount
# 0        1  2000.0  1.0       0.1
# 1        2  2000.0  2.0       0.2
# 2        2  2001.0  1.0       0.2
# 3        3  2001.0  2.0       1.0
# 4        4     NaN  NaN       NaN
# 5        5     NaN  NaN       NaN

# %% [markdown]
# There are three ways to do this:
# 1. `pd.MultiIndex.from_product` plus reshape
# 2. `pd.core.reshape.util.cartesian_product` plus constructing the DataFrame
# 3. Adding a useless column and then removing it.

# %%
# if we use the third method
df_1["key"], df_3["key"] = 1, 1
df_cross = pd.merge(df_1, df_3, on="key").drop("key", axis=1)
df_cross
# Out:
#     year  sem  fee  student
# 0   2000    1  200        1
# 1   2000    1  200        2
# 2   2000    1  200        3
# 3   2000    1  200        4
# 4   2000    1  200        5
# 5   2000    2  200        1
# 6   2000    2  200        2
# 7   2000    2  200        3
# 8   2000    2  200        4
# 9   2000    2  200        5
# 10  2001    1  200        1
# 11  2001    1  200        2
# 12  2001    1  200        3
# 13  2001    1  200        4
# 14  2001    1  200        5
# 15  2001    2  200        1
# 16  2001    2  200        2
# 17  2001    2  200        3
# 18  2001    2  200        4
# 19  2001    2  200        5

# %%
all_fees = pd.merge(df_cross, df_2, on=["student", "year", "sem"], how="left")
all_fees.discount.fillna(0, inplace=True)
all_fees["due"] = all_fees.fee * (1 - all_fees.discount)
all_fees
# Out:
#     year  sem  fee  student  discount    due
# 0   2000    1  200        1       0.1  180.0
# 1   2000    1  200        2       0.0  200.0
# 2   2000    1  200        3       0.0  200.0
# 3   2000    1  200        4       0.0  200.0
# 4   2000    1  200        5       0.0  200.0
# 5   2000    2  200        1       0.0  200.0
# 6   2000    2  200        2       0.2  160.0
# 7   2000    2  200        3       0.0  200.0
# 8   2000    2  200        4       0.0  200.0
# 9   2000    2  200        5       0.0  200.0
# 10  2001    1  200        1       0.0  200.0
# 11  2001    1  200        2       0.2  160.0
# 12  2001    1  200        3       0.0  200.0
# 13  2001    1  200        4       0.0  200.0
# 14  2001    1  200        5       0.0  200.0
# 15  2001    2  200        1       0.0  200.0
# 16  2001    2  200        2       0.0  200.0
# 17  2001    2  200        3       1.0    0.0
# 18  2001    2  200        4       0.0  200.0
# 19  2001    2  200        5       0.0  200.0

# %% [markdown]
# # Merging Functions

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_aus = pd.read_csv("aus.csv", parse_dates=["date"], dayfirst=True)
df_usa = pd.read_csv("usa.csv", parse_dates=["date"], dayfirst=True)
df_bris = pd.read_csv("brisbane.csv", parse_dates=["date"], dayfirst=True)

display(df_aus.head(), df_usa.head(), df_bris.head())
# Out:
#         date  temperature
# 0 2000-01-20         30.6
# 1 2001-01-20         32.7
# 2 2002-01-20         31.2
# 3 2003-01-20         30.5
# 4 2004-01-20         31.5
#         date  temperature
# 0 2000-03-01        15.25
# 1 2000-09-01        15.77
# 2 2001-03-01        15.98
# 3 2001-09-01        16.55
# 4 2002-03-01        15.32
#         date  temperature
# 0 2000-01-01        30.15
# 1 2000-01-08        30.31
# 2 2000-01-15        30.99
# 3 2000-01-22        30.94
# 4 2000-01-29        29.95

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

plt.plot(df_aus.date, df_aus.temperature, label="Aus")
plt.plot(df_usa.date, df_usa.temperature, label="USA")
plt.plot(df_bris.date, df_bris.temperature, label="Bris")
plt.legend();

# %% [markdown]
# # Ordered Merging

# %%
pd.merge(df_aus, df_usa, on="date", how="outer")
# Out:
#          date  temperature_x  temperature_y
# 0  2000-01-20           30.6            NaN
# 1  2001-01-20           32.7            NaN
# 2  2002-01-20           31.2            NaN
# 3  2003-01-20           30.5            NaN
# 4  2004-01-20           31.5            NaN
# 5  2005-01-20           32.4            NaN
# 6  2006-01-20           30.7            NaN
# 7  2007-01-20           32.5            NaN
# 8  2008-01-20           31.1            NaN
# 9  2009-01-20           33.4            NaN
# 10 2010-01-20           32.6            NaN
# 11 2011-01-20           32.3            NaN
# 12 2012-01-20           32.4            NaN
# 13 2013-01-20           32.5            NaN
# 14 2014-01-20           34.3            NaN
# 15 2015-01-20           35.0            NaN
# 16 2016-01-20           33.9            NaN
# 17 2017-01-20           36.5            NaN
# 18 2000-03-01            NaN          15.25
# 19 2000-09-01            NaN          15.77
# ...

# %%
pd.merge_ordered(df_aus, df_usa, on="date", suffixes=("_aus", "_usa")).head(10)
# Out:
#         date  temperature_aus  temperature_usa
# 0 2000-01-20             30.6              NaN
# 1 2000-03-01              NaN            15.25
# 2 2000-09-01              NaN            15.77
# 3 2001-01-20             32.7              NaN
# 4 2001-03-01              NaN            15.98
# 5 2001-09-01              NaN            16.55
# 6 2002-01-20             31.2              NaN
# 7 2002-03-01              NaN            15.32
# 8 2002-09-01              NaN            15.50
# 9 2003-01-20             30.5              NaN

# %%
# since we have many NaN, we are going to use ffill method to fill NaN by the previous number
pd.merge_ordered(df_aus, df_usa, on="date", suffixes=("_aus", "_usa"), fill_method="ffill")
# Out:
#          date  temperature_aus  temperature_usa
# 0  2000-01-20             30.6              NaN
# 1  2000-03-01             30.6            15.25
# 2  2000-09-01             30.6            15.77
# 3  2001-01-20             32.7            15.77
# 4  2001-03-01             32.7            15.98
# 5  2001-09-01             32.7            16.55
# 6  2002-01-20             31.2            16.55
# 7  2002-03-01             31.2            15.32
# 8  2002-09-01             31.2            15.50
# 9  2003-01-20             30.5            15.50
# 10 2003-03-01             30.5            17.18
# 11 2003-09-01             30.5            16.46
# 12 2004-01-20             31.5            16.46
# 13 2004-03-01             31.5            16.30
# 14 2004-09-01             31.5            16.33
# 15 2005-01-20             32.4            16.33
# 16 2005-03-01             32.4            15.45
# 17 2005-09-01             32.4            16.38
# 18 2006-01-20             30.7            16.38
# ...

# %% [markdown]
# # Merging with Partial/Closet Matches

# %%
df_both = pd.merge_ordered(df_aus, df_usa, on="date", suffixes=("_aus", "_usa"), fill_method="ffill")
df_all = pd.merge_asof(df_both, df_bris, on="date").rename(columns={"temperature": "temperature_bris"})
df_all.head(5)
# Out:
#         date  temperature_aus  temperature_usa  temperature_bris
# 0 2000-01-20             30.6              NaN             30.99
# 1 2000-03-01             30.6            15.25             29.31
# 2 2000-09-01             30.6            15.77             20.68
# 3 2001-01-20             32.7            15.77             24.71
# 4 2001-03-01             32.7            15.98             26.40

# %%
df_all.plot("date", ["temperature_aus", "temperature_usa", "temperature_bris"]);

# %%
# This has allowed us to pick out the dates corresponding to other measurements, which in this case correspond to the middle of summer and winter. 
# Notice the fill value on the right. We could remove that if we wanted.
df_tmp = pd.merge_asof(df_both, df_bris, on="date", 
                       tolerance=pd.Timedelta('14 days'), direction="nearest")
df_tmp.plot("date", df_tmp.columns[1:], legend=False);
